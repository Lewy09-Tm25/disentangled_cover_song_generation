# %%
import numpy as np
import soundfile as sf  # or scipy.io.wavfile

SR = 24_000
x = np.load("../project_output/cover_project_full/infer_out/wid_1634_shift_0_baseline_mono.npy").astype(np.float32)
sf.write("wid_1634_shift_0_baseline.wav", x, SR, subtype="PCM_16")
x = np.load("../project_output/cover_project_full/infer_out/wid_1743_shift_0_baseline_mono.npy").astype(np.float32)
sf.write("wid_1743_shift_0_baseline.wav", x, SR, subtype="PCM_16")
x = np.load("../project_output/cover_project_full/infer_out/wid_2061_shift_0_baseline_mono.npy").astype(np.float32)
sf.write("wid_2061_shift_0_baseline.wav", x, SR, subtype="PCM_16")
x = np.load("../project_output/cover_project_full/infer_out/wid_2204_shift_0_baseline_mono.npy").astype(np.float32)
sf.write("wid_2204_shift_0_baseline.wav", x, SR, subtype="PCM_16")
x = np.load("../project_output/cover_project_full/infer_out/wid_3816_shift_0_baseline_mono.npy").astype(np.float32)
sf.write("wid_3816_shift_0_baseline.wav", x, SR, subtype="PCM_16")
x = np.load("../project_output/cover_project_full/infer_out/wid_640_shift_0_baseline_mono.npy").astype(np.float32)
sf.write("wid_640_shift_0_baseline.wav", x, SR, subtype="PCM_16")
